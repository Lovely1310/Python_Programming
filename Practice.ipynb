# %%
# Month Days Calculation

# Write a Python program to convert a month name into the corresponding number
# of days. For invalid month names, print 'Wrong month name.'
# Note: February has either 28 or 29 days depending on whether it's a leap year.

# Example 1:
# Input:
# February

# Output:
# 28/29 days

# Explanation:
# This input checks the number of days in February, accounting for leap years.

# Example 2:
# Input:
# April

# Output:
# 30 days

# Explanation:
# April has 30 days.

# Example 3:
# Input:
# Augst

# Output:
# Wrong month name

# Explanation:
# "Augst" is a misspelling; the correct spelling is "August."



# Style	Description	Example
# upper()	All uppercase letters	"hello".upper() → HELLO
# lower()	All lowercase letters	"Hello".lower() → hello
# title()	First letter of each word capitalized	"hello world".title() → Hello World
# Camel Case	First word lowercase, next words capitalized	"hello world" → helloWorld
# Pascal Case	Every word capitalized (Upper Camel)	"hello world" → HelloWorld
# Snake Case	All lowercase with underscores	"hello world" → hello_world





# brute force approach of the solution
from datetime import datetime


# current_year = datetime.now().year
current_year = 2024

# print(current_year)


# month = "March"

month = input("Enter a month name: ").title()


if month == "January":
    print("30 Days")
elif month == "February":
    if (current_year%4==0 and current_year %100 !=0 ) or(current_year%400 == 0):
      print("29 Days because it's a leap year")
    else:
      print("28 Days because it's not a leap year")
elif month == "March":
    print("31 Days")
elif month == "April":
    print("30 Days")
elif month == "May":
    print("31 Days")
elif month == "June":
    print("30 Days")
elif month == "July":
    print("31 Days")
elif month == "August":
    print("31 Days")
elif month == "September":
    print("30 Days")
elif month == "October":
    print("31 Days")
elif month == "November":
    print("30 Days")
elif month == "December":
    print("31 Days")
else:
    print("Wrong Month name")

# %%
month = input("Input the name of Month: ").strip()
# (year % 400==0 ) or (year %4 ==0 and year%100!=0)
